# %%
import pandas as pd
bbl = pd.read_csv('bblid_renamed.csv')
dat = pd.read_csv('pnc_demographic.csv')

datx =pd.read_csv('pncdata_summary.csv')

daty =datx.merge(bbl, on='sub')
daty =daty.merge(dat, on='sub')
dat.head()
# Out:
#    bblid  scanid  sex  race  race2  ethnicity  ageAtClinicalAssess1  \
# 0  80010    2894    1     1      1          2                   260
# 1  80179    2643    2     1      1          2                   254
# 2  80199    2637    1     5      3          1                   243
# 3  80208    3016    1     2      2          2                   245
# 4  80249    2648    2     1      1          2                   250
#
#    ageAtCnb1  ageAtScan1  edu1  fedu1  medu1  handednessv2        age  \
# 0        260         261    14   20.0   16.0             1  21.750000
# 1        254         254    12    NaN   14.0             1  21.166667
# 2        244         244    12    NaN   12.0             1  20.333333
# 3        245         246    11   12.0   12.0             2  20.500000
# 4        250         250    16   10.0   12.0             1  20.833333
#
#           sub
# 0  1832999514
# 1  2216595430
# 2  1867827374
# 3   278814796
# 4  3103368139

# %%
datax = dat[['bblid','scanid','sub']]
datax.to_csv('bblid_scanid_sub.csv',index=False)

# %%
dat
# Out:
# (1629,)

# %%
bbl.drop_duplicates()
# Out:
#        bblid         sub
# 0      80010  1832999514
# 1      80027  1208119374
# 2      80036  2480776643
# 3      80043  1190434769
# 4      80051  1020002775
# ...      ...         ...
# 9493  139571  1808549573
# 9494  139601    15942680
# 9495  139604  3879912983
# 9496  139616   329939114
# 9497  139633   546776987
#
# [9498 rows x 2 columns]

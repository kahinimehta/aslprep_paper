# %%
library(ggplot2)
library(mgcv)
datax=read.csv('smoothfw.csv')
datax
# Out:
#      scanid oldpnc   cbf      scrub    basil     pvc
# 1    2894   5.052893 5.782318 5.988785 9.149855  13.288173
# 2    2643   7.627928 6.733574 6.952269 9.825252  11.617635
# 3    2637   6.470346 5.484061 5.631169 7.943851  10.528908
# 4    3016   6.532078 6.245830 6.215336 9.801712  14.613882
# 5    2648   3.929853 5.265160 5.325229 8.373819  12.694086
# 6    6635   7.127022 6.543450 6.698912 9.067470  14.257679
# 7    3145   6.847510 6.760796 7.119543 9.202658  11.986121
# 8    2794   6.434876 5.570983 5.736728 8.851013  12.152425
# 9    7390   7.156925 6.035547 6.326032 9.534455  12.792836
# 10   2798   3.336568 5.749149 5.897509 7.938692  11.112753
# 11   2726   5.183260 6.304974 6.628028 8.806523  11.976853
# 12   3013   5.208398 4.946262 5.422068 7.816863  10.165408
# 13   2823   6.426241 6.492930 6.566077 8.890961  12.840260
# 14   3476   5.863575 6.077184 6.242882 8.931051  11.855352
# 15   2725   4.736186 5.912343 6.305409 8.889738  11.529193
# ...

# %%
ggplot(datax, aes(x=oldpnc, y=cbf)) + 
        geom_abline() + geom_point() + xlim(.1, 10)+ ylim(0.1,10) +
  labs(x = "oldpnc", y = "CBF",) +theme(axis.title.x = element_text(size = rel(1.2))) + 
   theme(axis.title.y = element_text(size = rel(1.2)))
# Out:
# Warning message:
# “Removed 1 rows containing missing values (geom_point).”
# plot without title

# %%
from nilearn import plotting
import pandas as pd 
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import nibabel as nb
# Out:
# /Users/adebimpe/anaconda3/lib/python3.8/site-packages/nilearn/datasets/__init__.py:86: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   warn("Fetchers from the nilearn.datasets module will be "

# %%
fig, axs = plt.subplots(5,5, sharex=False, sharey=True,dpi=800,figsize=(15,20))
plt.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='off')

nkicbf='/Users/adebimpe/Documents/aslprep_paper/scriptsx/nkidata/cbfmean/cbffile_mean.nii.gz'
nkiscrub='/Users/adebimpe/Documents/aslprep_paper/scriptsx/nkidata/cbfmean/scrubfile_mean.nii.gz'
nkibasil='/Users/adebimpe/Documents/aslprep_paper/scriptsx/nkidata/cbfmean/basilfile_mean.nii.gz'
nkipvc='/Users/adebimpe/Documents/aslprep_paper/scriptsx/nkidata/cbfmean/pvcgmfile_mean.nii.gz'
nkipvcw='/Users/adebimpe/Documents/aslprep_paper/scriptsx/nkidata/cbfmean/pvcwmfile_mean.nii.gz'

pnccbf='/Users/adebimpe/Documents/aslprep_paper/scriptsx/pncdata/cbfmean/cbffile_mean.nii.gz'
pncscrub='/Users/adebimpe/Documents/aslprep_paper/scriptsx/pncdata/cbfmean/scrubfile_mean.nii.gz'
pncbasil='/Users/adebimpe/Documents/aslprep_paper/scriptsx/pncdata/cbfmean/basilfile_mean.nii.gz'
pncpvc='/Users/adebimpe/Documents/aslprep_paper/scriptsx/pncdata/cbfmean/pvcgmfile_mean.nii.gz'
pncpvcw='/Users/adebimpe/Documents/aslprep_paper/scriptsx/pncdata/cbfmean/pvcwmfile_mean.nii.gz'


irrcbf='/Users/adebimpe/Documents/aslprep_paper/scriptsx/grympydata/cbfmean/cbffile_mean.nii.gz'
irrscrub='/Users/adebimpe/Documents/aslprep_paper/scriptsx/grympydata/cbfmean/scrubfile_mean.nii.gz'
irrbasil='/Users/adebimpe/Documents/aslprep_paper/scriptsx/grympydata/cbfmean/basilfile_mean.nii.gz'
irrpvc='/Users/adebimpe/Documents/aslprep_paper/scriptsx/grympydata/cbfmean/pvcgmfile_mean.nii.gz'
irrpvcw='/Users/adebimpe/Documents/aslprep_paper/scriptsx/grympydata/cbfmean/pvcwmfile_mean.nii.gz'

agecbf='/Users/adebimpe/Documents/aslprep_paper/scriptsx/ageingdata/cbfmean/cbf.nii.gz'
agescrub='/Users/adebimpe/Documents/aslprep_paper/scriptsx/ageingdata/cbfmean/scrub.nii.gz'
agebasil='/Users/adebimpe/Documents/aslprep_paper/scriptsx/ageingdata/cbfmean/basil.nii.gz'
agepvc='/Users/adebimpe/Documents/aslprep_paper/scriptsx/ageingdata/cbfmean/pvc.nii.gz'
agepvcw='/Users/adebimpe/Documents/aslprep_paper/scriptsx/ageingdata/cbfmean/pvcwmfile_mean.nii.gz'


cdcbf='/Users/adebimpe/Documents/aslprep_paper/scriptsx/ftddata/cbfmean/cbf.nii.gz'
#cdscrub='/Users/adebimpe/Documents/aslprep_paper/scripts/ageingdata/cbfmean/scrubfile_mean.nii.gz'
cdbasil='/Users/adebimpe/Documents/aslprep_paper/scriptsx/ftddata/cbfmean/basil.nii.gz'
cdpvc='/Users/adebimpe/Documents/aslprep_paper/scriptsx/ftddata/cbfmean/pvc.nii.gz'
cdpvcw='/Users/adebimpe/Documents/aslprep_paper/scriptsx/ftddata/cbfmean/pvcwmfile_mean.nii.gz'



template=None
cmap1='coolwarm'
th=2
plotting.plot_stat_map(pnccbf,
                       cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=90,colorbar=False,draw_cross=False,axes=axs[0,0])

plotting.plot_stat_map(pncscrub,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=90,colorbar=False,draw_cross=False,axes=axs[0,1])
plotting.plot_stat_map(pncbasil,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=90,colorbar=False,draw_cross=False,axes=axs[0,2])
plotting.plot_stat_map(pncpvc,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=90,colorbar=False,draw_cross=False,axes=axs[0,3])

plotting.plot_stat_map(pncpvcw,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[-2],annotate=False,
                       threshold=th,vmax=90,colorbar=False,draw_cross=False,axes=axs[0,4])




plotting.plot_stat_map(nkicbf,cmap=cmap1,
                       bg_img=template,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=90,colorbar=False,draw_cross=False,axes=axs[1,0])

plotting.plot_stat_map(nkiscrub,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=90,colorbar=False,draw_cross=False,axes=axs[1,1])
plotting.plot_stat_map(nkibasil,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=90,colorbar=False,draw_cross=False,axes=axs[1,2])
plotting.plot_stat_map(nkipvc,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=90,colorbar=False,draw_cross=False,axes=axs[1,3])
plotting.plot_stat_map(nkipvcw,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=90,colorbar=False,draw_cross=False,axes=axs[1,4])



plotting.plot_stat_map(irrcbf,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=5,vmax=90,colorbar=False,draw_cross=False,axes=axs[2,0])

plotting.plot_stat_map(irrscrub,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=90,colorbar=False,draw_cross=False,axes=axs[2,1])
plotting.plot_stat_map(irrbasil,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=90,colorbar=False,draw_cross=False,axes=axs[2,2])
plotting.plot_stat_map(irrpvc,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=90,colorbar=False,draw_cross=False,axes=axs[2,3])

plotting.plot_stat_map(irrpvcw,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=90,colorbar=False,draw_cross=False,axes=axs[2,4])



plotting.plot_stat_map(agecbf,cmap=cmap1,
                       bg_img=template,threshold=th,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[-2],annotate=False,
                       vmax=90,colorbar=False,draw_cross=False,axes=axs[3,0])

plotting.plot_stat_map(agescrub,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[-2],annotate=False,
                       threshold=th,vmax=90,colorbar=False,draw_cross=False,axes=axs[3,1])
plotting.plot_stat_map(agebasil,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[-2],annotate=False,
                       threshold=th,vmax=90,colorbar=False,draw_cross=False,axes=axs[3,2])
plotting.plot_stat_map(agepvcw,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[-2],annotate=False,
                       threshold=th,vmax=90,colorbar=False,draw_cross=False,axes=axs[3,3])

plotting.plot_stat_map(agepvc,
                       cmap=cmap1,bg_img=template,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[-2],annotate=False,
                       threshold=th,vmax=90,colorbar=False,draw_cross=False,axes=axs[3,4])

plotting.plot_stat_map(agecbf,
                       cmap=cmap1,bg_img=template,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[-2],annotate=False,
                       threshold=th,vmax=90,colorbar=False,draw_cross=False,axes=axs[4,0])


plotting.plot_stat_map(agebasil,
                       cmap=cmap1,bg_img=template,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[-2],annotate=False,
                       threshold=th,vmax=90,colorbar=False,draw_cross=False,axes=axs[4,2])
plotting.plot_stat_map(agepvc,
                       cmap=cmap1,bg_img=template,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[-2],annotate=False,
                       threshold=th,vmax=90,colorbar=False,draw_cross=False,axes=axs[4,3])

plotting.plot_stat_map(agepvcw,bg_img=template,
                       cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[-2],annotate=False,
                       threshold=th,vmax=90,colorbar=False,draw_cross=False,axes=axs[4,4])




plt.savefig('sup_figure3.png', dpi=800)

# %%
fig, axs = plt.subplots(5,5, sharex=False, sharey=True,dpi=800,figsize=(15,20))
plt.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='off')

nkicbf='/Users/adebimpe/Documents/aslprep_paper/scriptsx/nkidata/cbfmean/sub-A00080052_space-FSL_cbf.nii.gz'
nkiscrub='/Users/adebimpe/Documents/aslprep_paper/scriptsx/nkidata/cbfmean/sub-A00080052_space-FSL_scrub.nii.gz'
nkibasil='/Users/adebimpe/Documents/aslprep_paper/scriptsx/nkidata/cbfmean/sub-A00080052_space-FSL_basil.nii.gz'
nkipvc='/Users/adebimpe/Documents/aslprep_paper/scriptsx/nkidata/cbfmean/sub-A00080052_space-FSL_pvGM.nii.gz'
nkipvcw='/Users/adebimpe/Documents/aslprep_paper/scriptsx/nkidata/cbfmean/sub-A00080052_space-FSL_pvWM.nii.gz'

pnccbf='/Users/adebimpe/Documents/aslprep_paper/scriptsx/pncdata/cbfmean/sub-3614947229_acq-se_space-FSL_cbf.nii.gz'
pncscrub='/Users/adebimpe/Documents/aslprep_paper/scriptsx/pncdata/cbfmean/sub-3614947229_acq-se_space-FSL_scrub.nii.gz'
pncbasil='/Users/adebimpe/Documents/aslprep_paper/scriptsx/pncdata/cbfmean/sub-3614947229_acq-se_space-FSL_basil.nii.gz'
pncpvc='/Users/adebimpe/Documents/aslprep_paper/scriptsx/pncdata/cbfmean/sub-3614947229_acq-se_space-FSL_pvGM.nii.gz'
pncpvcw='/Users/adebimpe/Documents/aslprep_paper/scriptsx/pncdata/cbfmean/sub-3614947229_acq-se_space-FSL_pvWM.nii.gz'


irrcbf='/Users/adebimpe/Documents/aslprep_paper/scriptsx/grympydata/cbfmean/sub-80557_space-FSL_cbf.nii.gz'
irrscrub='/Users/adebimpe/Documents/aslprep_paper/scriptsx/grympydata/cbfmean/sub-80557_space-FSL_scrub.nii.gz'
irrbasil='/Users/adebimpe/Documents/aslprep_paper/scriptsx/grympydata/cbfmean/sub-80557_space-FSL_basil.nii.gz'
irrpvc='/Users/adebimpe/Documents/aslprep_paper/scriptsx/grympydata/cbfmean/sub-80557_space-FSL_pvGM.nii.gz'
irrpvcw='/Users/adebimpe/Documents/aslprep_paper/scriptsx/grympydata/cbfmean/sub-80557_space-FSL_pvWM.nii.gz'

agecbf='/Users/adebimpe/Documents/aslprep_paper/scriptsx/ageingdata/cbfmean/sub-38_space-FSL_cbf.nii.gz'
agescrub='/Users/adebimpe/Documents/aslprep_paper/scriptsx/ageingdata/cbfmean/sub-38_space-FSL_scrub.nii.gz'
agebasil='/Users/adebimpe/Documents/aslprep_paper/scriptsx/ageingdata/cbfmean/sub-38_space-FSL_basil.nii.gz'
agepvc='/Users/adebimpe/Documents/aslprep_paper/scriptsx/ageingdata/cbfmean/sub-38_space-FSL_pvGM.nii.gz'
agepvcw='/Users/adebimpe/Documents/aslprep_paper/scriptsx/ageingdata/cbfmean/sub-38_space-FSL_pvWM.nii.gz'


cdcbf='/Users/adebimpe/Documents/aslprep_paper/scriptsx/ageingdata/cbfmean/sub-36_space-FSL_cbf.nii.gz'
#cdscrub='/Users/adebimpe/Documents/aslprep_paper/scripts/ageingdata/cbfmean/sub-62_space-FSL_scrub.nii.gz'
cdbasil='/Users/adebimpe/Documents/aslprep_paper/scriptsx/ageingdata/cbfmean/sub-36_space-FSL_basil.nii.gz'
cdpvc='/Users/adebimpe/Documents/aslprep_paper/scriptsx/ageingdata/cbfmean/sub-36_space-FSL_pvGM.nii.gz'
cdpvcw='/Users/adebimpe/Documents/aslprep_paper/scriptsx/ageingdata/cbfmean/sub-36_space-FSL_pvWM.nii.gz'


th=1
template=None
cmap1='coolwarm'
plotting.plot_stat_map(pnccbf,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=100,colorbar=False,draw_cross=False,axes=axs[0,0])

plotting.plot_stat_map(pncscrub,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=100,colorbar=False,draw_cross=False,axes=axs[0,1])
plotting.plot_stat_map(pncbasil,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=100,colorbar=False,draw_cross=False,axes=axs[0,2])
plotting.plot_stat_map(pncpvc,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=100,colorbar=False,draw_cross=False,axes=axs[0,3])

plotting.plot_stat_map(pncpvcw,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=100,colorbar=False,draw_cross=False,axes=axs[0,4])




plotting.plot_stat_map(nkicbf,cmap=cmap1,
                       bg_img=template,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=100,colorbar=False,draw_cross=False,axes=axs[1,0])

plotting.plot_stat_map(nkiscrub,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=100,colorbar=False,draw_cross=False,axes=axs[1,1])
plotting.plot_stat_map(nkibasil,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=100,colorbar=False,draw_cross=False,axes=axs[1,2])
plotting.plot_stat_map(nkipvc,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=100,colorbar=False,draw_cross=False,axes=axs[1,3])
plotting.plot_stat_map(nkipvcw,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=100,colorbar=False,draw_cross=False,axes=axs[1,4])



plotting.plot_stat_map(irrcbf,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=100,colorbar=False,draw_cross=False,axes=axs[2,0])

plotting.plot_stat_map(irrscrub,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=100,colorbar=False,draw_cross=False,axes=axs[2,1])
plotting.plot_stat_map(irrbasil,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=100,colorbar=False,draw_cross=False,axes=axs[2,2])
plotting.plot_stat_map(irrpvc,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=100,colorbar=False,draw_cross=False,axes=axs[2,3])

plotting.plot_stat_map(irrpvcw,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=100,colorbar=False,draw_cross=False,axes=axs[2,4])



plotting.plot_stat_map(agecbf,cmap=cmap1,
                       bg_img=template,threshold=th,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       vmax=120,colorbar=False,draw_cross=False,axes=axs[3,0])

plotting.plot_stat_map(agescrub,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=100,colorbar=False,draw_cross=False,axes=axs[3,1])
plotting.plot_stat_map(agebasil,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=100,colorbar=False,draw_cross=False,axes=axs[3,2])
plotting.plot_stat_map(agepvcw,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=100,colorbar=False,draw_cross=False,axes=axs[3,3])

plotting.plot_stat_map(agepvc,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=100,colorbar=False,draw_cross=False,axes=axs[3,4])

plotting.plot_stat_map(cdcbf,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=100,colorbar=False,draw_cross=False,axes=axs[4,0])


plotting.plot_stat_map(cdbasil,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=100,colorbar=False,draw_cross=False,axes=axs[4,2])
plotting.plot_stat_map(cdpvc,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=100,colorbar=False,draw_cross=False,axes=axs[4,3])

plotting.plot_stat_map(cdpvcw,
                       bg_img=template,cmap=cmap1,
                       symmetric_cbar=True,black_bg=False,display_mode="z", cut_coords=[0],annotate=False,
                       threshold=th,vmax=100,colorbar=False,draw_cross=False,axes=axs[4,4])




plt.savefig('sup_figure2.png', dpi=800)
